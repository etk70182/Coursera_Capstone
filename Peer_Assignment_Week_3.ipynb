# %% [markdown]
# # Week 3 - Applied Data Science Capstone - Peer Assignment

# %% [markdown]
# ### Introduction
#
# In this assignment the table of the postal codes published in the wikipedia article will be scraped.

# %%
import numpy as np # library to handle data in a vectorized manner
import pandas as pd # library for data analysis

from bs4 import BeautifulSoup # library for website scraping
import requests

# %% [markdown]
# ### 1. Scrape table from wikipedia webpage

# %%
source = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text # Get source code of wikipedia webpage

soup   = BeautifulSoup(source, 'lxml') # Use library to scrape source code
tables = soup.find_all('table', class_='sortable') # Find all tables contained in the source code

for table in tables: # Iterate over tables
    ths = table.find_all('th') # Find table header
    headings = [th.text.strip() for th in ths]
    if headings[:3] == ['Postcode', 'Borough', 'Neighbourhood']:
        break
        
df      = pd.DataFrame(columns=headings) # Create dataframe with headings

for i, tr in enumerate(table.find_all('tr')): # iterate over table
    tds = tr.find_all('td')
    if not tds:
        continue
    postcode, borough, neighbourhood = [td.text.strip() for td in tds[:3]] # Strip text and assign to dataframe
    df.loc[i, 'Postcode']       = postcode
    df.loc[i, 'Borough']        = borough
    df.loc[i, 'Neighbourhood']  = neighbourhood
    
df.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 1      M1A      Not assigned      Not assigned
# 2      M2A      Not assigned      Not assigned
# 3      M3A        North York         Parkwoods
# 4      M4A        North York  Victoria Village
# 5      M5A  Downtown Toronto      Harbourfront

# %% [markdown]
# ### 2. Only process the cells that have an assigned borough

# %%
df.replace('Not assigned', np.nan, regex=True, inplace=True) # Replace string with np.nan
df.dropna(subset=['Borough'], inplace=True) # Apply drop nan function of pandas on dataframe

# %% [markdown]
# ### 3. Combine neighbourhoods into one row separated with a comma and assign __Not assigned__ neighbourhoods the same as borough

# %%
def to_comma_sep_row(df):
    if df['Neighbourhood'].dropna().size == 0:
        df['Neighbourhood'] = df['Borough']
    else:
        df['Neighbourhood'] = ', '.join(df['Neighbourhood'].unique().tolist())
    return df
    
df = df.groupby(['Postcode', 'Borough']).apply(to_comma_sep_row).drop_duplicates()

# %%
df.head()
# Out:
#   Postcode           Borough                     Neighbourhood
# 3      M3A        North York                         Parkwoods
# 4      M4A        North York                  Victoria Village
# 5      M5A  Downtown Toronto         Harbourfront, Regent Park
# 7      M6A        North York  Lawrence Heights, Lawrence Manor
# 9      M7A      Queen's Park                      Queen's Park

# %% [markdown]
# ### 4. Print number of rows of dataframe

# %%
df.shape
# Out:
# (103, 3)

# %% [markdown]
# ### 5. Final table

# %%
df.head(50)
# Out:
#     Postcode           Borough  \
# 3        M3A        North York
# 4        M4A        North York
# 5        M5A  Downtown Toronto
# 7        M6A        North York
# 9        M7A      Queen's Park
# 11       M9A         Etobicoke
# 12       M1B       Scarborough
# 15       M3B        North York
# 16       M4B         East York
# 18       M5B  Downtown Toronto
# 20       M6B        North York
# 23       M9B         Etobicoke
# 28       M1C       Scarborough
# 32       M3C        North York
# 34       M4C         East York
# 35       M5C  Downtown Toronto
# 36       M6C              York
# 39       M9C         Etobicoke
# 43       M1E       Scarborough
# 48       M4E      East Toronto
# 49       M5E  Downtown Toronto
# 50       M6E              York
# 54       M1G       Scarborough
# 57       M4G         East York
# 58       M5G  Downtown Toronto
# 59       M6G  Downtown Toronto
# 63       M1H       Scarborough
# 64       M2H        North York
# 65       M3H        North York
# 68       M4H         East York
# 69       M5H  Downtown Toronto
# 72       M6H      West Toronto
# 77       M1J       Scarborough
# 78       M2J        North York
# 81       M3J        North York
# 83       M4J         East York
# 84       M5J  Downtown Toronto
# 87       M6J      West Toronto
# 92       M1K       Scarborough
# 95       M2K        North York
# 96       M3K        North York
# 98       M4K      East Toronto
# 100      M5K  Downtown Toronto
# 102      M6K      West Toronto
# 108      M1L       Scarborough
# 111      M2L        North York
# 113      M3L        North York
# 114      M4L      East Toronto
# 116      M5L  Downtown Toronto
# 118      M6L        North York
#
#                                          Neighbourhood
# 3                                            Parkwoods
# 4                                     Victoria Village
# 5                            Harbourfront, Regent Park
# 7                     Lawrence Heights, Lawrence Manor
# 9                                         Queen's Park
# 11                                    Islington Avenue
# 12                                      Rouge, Malvern
# 15                                     Don Mills North
# 16                     Woodbine Gardens, Parkview Hill
# 18                            Ryerson, Garden District
# 20                                           Glencairn
# 23   Cloverdale, Islington, Martin Grove, Princess ...
# 28              Highland Creek, Rouge Hill, Port Union
# 32                    Flemingdon Park, Don Mills South
# 34                                    Woodbine Heights
# 35                                      St. James Town
# 36                                  Humewood-Cedarvale
# 39   Bloordale Gardens, Eringate, Markland Wood, Ol...
# 43                   Guildwood, Morningside, West Hill
# 48                                         The Beaches
# 49                                         Berczy Park
# 50                                 Caledonia-Fairbanks
# 54                                              Woburn
# 57                                             Leaside
# 58                                  Central Bay Street
# 59                                            Christie
# 63                                           Cedarbrae
# 64                                   Hillcrest Village
# 65     Bathurst Manor, Downsview North, Wilson Heights
# 68                                    Thorncliffe Park
# 69                            Adelaide, King, Richmond
# 72                        Dovercourt Village, Dufferin
# 77                                 Scarborough Village
# 78                        Fairview, Henry Farm, Oriole
# 81                     Northwood Park, York University
# 83                                        East Toronto
# 84   Harbourfront East, Toronto Islands, Union Station
# 87                            Little Portugal, Trinity
# 92         East Birchmount Park, Ionview, Kennedy Park
# 95                                     Bayview Village
# 96                         CFB Toronto, Downsview East
# 98                        The Danforth West, Riverdale
# 100           Design Exchange, Toronto Dominion Centre
# 102       Brockton, Exhibition Place, Parkdale Village
# 108                    Clairlea, Golden Mile, Oakridge
# 111                           Silver Hills, York Mills
# 113                                     Downsview West
# 114                     The Beaches West, India Bazaar
# 116                     Commerce Court, Victoria Hotel
# 118           Maple Leaf Park, North Park, Upwood Park
